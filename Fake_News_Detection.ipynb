# %%
import numpy as np
import pandas as pd

# %%
fake=pd.read_csv(r'C:\Users\IDEAL COM\Downloads\Fake.csv')
true=pd.read_csv(r'C:\Users\IDEAL COM\Downloads\True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true['label']=1
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news=pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
fake.shape,true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
news.shape
# Out:
# (44898, 5)

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news=news.sample(frac=1)
news.head()
# Out:
#                                                     text  label
# 3995    WASHINGTON (Reuters) - He misses driving, fee...      1
# 18338  MSNBC s Casey Hunt was interviewing war-hawk a...      0
# 7252   Appearing on ABC s This Week with host Jonatha...      0
# 2527   BERLIN (Reuters) - Germany warned on Wednesday...      1
# 16762  TOKYO (Reuters) - A rapidly weakening typhoon ...      1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   3995   WASHINGTON (Reuters) - He misses driving, fee...      1
# 1  18338  MSNBC s Casey Hunt was interviewing war-hawk a...      0
# 2   7252  Appearing on ABC s This Week with host Jonatha...      0
# 3   2527  BERLIN (Reuters) - Germany warned on Wednesday...      1
# 4  16762  TOKYO (Reuters) - A rapidly weakening typhoon ...      1

# %%
news.drop(columns='index',inplace=True)

# %%
news.head()
# Out:
#                                                 text  label
# 0   WASHINGTON (Reuters) - He misses driving, fee...      1
# 1  MSNBC s Casey Hunt was interviewing war-hawk a...      0
# 2  Appearing on ABC s This Week with host Jonatha...      0
# 3  BERLIN (Reuters) - Germany warned on Wednesday...      1
# 4  TOKYO (Reuters) - A rapidly weakening typhoon ...      1

# %%
import re

# %%
def wordopt(text):
    text=text.lower()
    text=re.sub(r'https?://\S+|www\.\S+','',text)
    text=re.sub(r'<.*?>','',text)
    text=re.sub(r'\d','',text)
    text=re.sub(r'[^\w\s]','',text)
    text=re.sub(r'\n','',text)
    return text

# %%
news['text']=news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0         washington reuters  he misses driving feels a...
# 1        msnbc s casey hunt was interviewing warhawk an...
# 2        appearing on abc s this week with host jonatha...
# 3        berlin reuters  germany warned on wednesday it...
# 4        tokyo reuters  a rapidly weakening typhoon lan...
#                                ...
# 44893    reuters  wall streets predilection for a glass...
# 44894    this letter was sent to  fed up by an anonymou...
# 44895    amman reuters  jets believed to be syrian and ...
# 44896    bamako reuters  mali s president ibrahim bouba...
# 44897    apparently using thug michael ferguson s mom a...
# Name: text, Length: 44898, dtype: object

# %%
x=news['text']
y=news['label']

# %%
x
# Out:
# 0         washington reuters  he misses driving feels a...
# 1        msnbc s casey hunt was interviewing warhawk an...
# 2        appearing on abc s this week with host jonatha...
# 3        berlin reuters  germany warned on wednesday it...
# 4        tokyo reuters  a rapidly weakening typhoon lan...
#                                ...
# 44893    reuters  wall streets predilection for a glass...
# 44894    this letter was sent to  fed up by an anonymou...
# 44895    amman reuters  jets believed to be syrian and ...
# 44896    bamako reuters  mali s president ibrahim bouba...
# 44897    apparently using thug michael ferguson s mom a...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 44893    1
# 44894    0
# 44895    1
# 44896    1
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((35918,), (8980,), (35918,), (8980,))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer()

# %%
xv_train=vectorizer.fit_transform(x_train)
xv_text=vectorizer.transform(x_test)

# %%
xv_train
# Out:
# <35918x185904 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7352708 stored elements in Compressed Sparse Row format>

# %%
xv_text
# Out:
# <8980x185904 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1841464 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_pred=lr.predict(xv_text)

# %%
lr.score(xv_text,y_test)
# Out:
# 0.988641425389755

# %%
from sklearn.metrics import accuracy_score,f1_score,recall_score,classification_report

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4631
#            1       0.99      0.99      0.99      4349
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC=DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc=DTC.predict(xv_text)

# %%
DTC.score(xv_text,y_test)
# Out:
# 0.99543429844098

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4631
#            1       1.00      0.99      1.00      4349
#
#     accuracy                           1.00      8980
#    macro avg       1.00      1.00      1.00      8980
# weighted avg       1.00      1.00      1.00      8980

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc=rfc.predict(xv_text)

# %%
rfc.score(xv_text,y_test)
# Out:
# 0.9888641425389755

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4631
#            1       0.99      0.99      0.99      4349
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
gbc.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
lr_gbc=gbc.predict(xv_text)

# %%
print(classification_report(y_test,lr_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      4631
#            1       0.99      1.00      1.00      4349
#
#     accuracy                           1.00      8980
#    macro avg       1.00      1.00      1.00      8980
# weighted avg       1.00      1.00      1.00      8980

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb=MultinomialNB()

# %%
nb.fit(xv_train,y_train)
# Out:
# MultinomialNB()

# %%
naive_lr=nb.predict(xv_text)

# %%
print(classification_report(y_test,naive_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      4631
#            1       0.94      0.95      0.95      4349
#
#     accuracy                           0.95      8980
#    macro avg       0.95      0.95      0.95      8980
# weighted avg       0.95      0.95      0.95      8980

# %%
news
# Out:
#                                                     text  label
# 0       washington reuters  he misses driving feels a...      1
# 1      msnbc s casey hunt was interviewing warhawk an...      0
# 2      appearing on abc s this week with host jonatha...      0
# 3      berlin reuters  germany warned on wednesday it...      1
# 4      tokyo reuters  a rapidly weakening typhoon lan...      1
# ...                                                  ...    ...
# 44893  reuters  wall streets predilection for a glass...      1
# 44894  this letter was sent to  fed up by an anonymou...      0
# 44895  amman reuters  jets believed to be syrian and ...      1
# 44896  bamako reuters  mali s president ibrahim bouba...      1
# 44897  apparently using thug michael ferguson s mom a...      0
#
# [44898 rows x 2 columns]

# %%
def output_label(n):
    if n==0:
        return 'This is Fake News'
    elif n==1:
        return 'This is Geniune News'

# %%
def manual_testing(news):
    testing_news={'text':[news]}
    new_def_test=pd.DataFrame(testing_news)
    new_def_test['text']=new_def_test['text'].apply(wordopt)
    new_x_test=new_def_test['text']
    new_xv_test=vectorizer.transform(new_x_test)
    pred_lr=lr.predict(new_xv_test)
    pred_gbc=gbc.predict(new_xv_test)
    pred_rfc=rfc.predict(new_xv_test)
    return '\n\nlr prediction:{} \ngbc prediction:{} \nrfc prediction:{}'.format(output_label(pred_lr[0]),output_label(pred_gbc[0]),output_label(pred_rfc[0]))

# %%
news_artical=str(input())
